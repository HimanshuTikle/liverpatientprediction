# %% [markdown]
# #  Liver Patient Prediction Project

# %% [markdown]
# # Domain Analysis:

# %% [markdown]
# __Age__ :
# • It tells the age of the person.
#
# **Gender** :
# • It tells the gender of the person(Male/Female).
#
# __Total Bilirubin(TB)__ :
# • A bilirubin test measures the amount of bilirubin in your blood.
#
# • It’s used to help find the cause of health conditions like jaundice, anemia, and liver disease.
#
# • Bilirubin is an orange-yellow pigment that occurs normally when part of your red blood cells break down.
#
# • Your liver takes the bilirubin from your blood and changes its chemical make-up so that most of it is passed through your       poop as bile.
#
# • If your bilirubin levels are higher than normal, it’s a sign that either your red blood cells are breaking down at an           unusual rate or that your liver isn’t breaking down waste properly and clearing the bilirubin from your blood.
#
# • Another option is that there’s a problem somewhere along the pathway that gets the bilirubin out of your liver and into         your stool.
# • All the bilirubin in your blood together is called total bilirubin.
#
# • Normal range : 0.1 to 1.2 mg/dL.
#
# __Direct Bilirubin(DB)__ :
# • Bilirubin attached by the liver to glucuronic acid, a glucose-derived acid, is called direct, or conjugated, bilirubin.
#
# • Bilirubin not attached to glucuronic acid is called indirect, or unconjugated, bilirubin.
#
# • Direct Bilirubin test is more valuable than total bilirubin for predicting prognosis in patients.
#
# • Higher level of Direct Bilirubin indicates your liver is not clearing bilirubin properly  and have a high chance of liver       disease.
#
# • Normal range : 0 to 0.4 mg/dL.
#
# __Alkaline Phosphatase(Alkphos)__ :
# • Alkaline phosphatase (AP) is an enzyme in a person's blood that helps break down proteins.
#
# • The body uses AP for a wide range of processes, and it plays a particularly important role in liver function and bone           development.
#
# • Using an AP test, it is possible to measure how much of this enzyme is circulating in a person’s blood.
#
# • Normal range : 44 to 147 IU/L.
#
# __Alanine Aminotransferase(Sgpt)__ :
# • Alanine aminotransferase (ALA) is an enzyme found primarily in the liver and kidney.
#
# • It was originally referred to as serum glutamic pyruvic transaminase(SGPT).
#
# • Normally, a low level of ALA exists in the serum.
#
# • ALA is increased with liver damage and is used to screen for and/or monitor liver disease.
#
# • Alanine aminotransferase (ALA) is usually measured concurrently with AST as part of a liver function panel to determine the     source of organ damage.
#
# • Normal range : 7 to 56 IU/L.
#
# __Asparate Aminotransferase(Sgot)__ :
# • AST (aspartate aminotransferase) is an enzyme that is found mostly in the liver, but also in muscles.
#
# • When your liver is damaged, it releases AST into your bloodstream.
#
# • An AST blood test measures the amount of AST in your blood.
#
# • The test can help your health care provider diagnose liver damage or disease.
#
# • Normal range : 5 to 40 IU/L.
#
# __Total Proteins(TP)__ :
# • Albumin and globulin are two types of protein in your body.
#
# • The total protein test measures the total amount albumin and globulin in your body.
#
# • It's used as part of your routine health checkup.
#
# • It may also be used if you have unexpected weight loss, fatigue, or the symptoms of a kidney or liver disease.
#
# • Normal range : 6 and 8.3 g/dL.
#
# __Albumin(ALB)__:
# • Albumin is a protein made by your liver.
#
# • Albumin helps keep fluid in your bloodstream so it doesn't leak into other tissues.
#
# • It is also carries various substances throughout your body, including hormones, vitamins, and enzymes.
#
# • Low albumin levels can indicate a problem with your liver or kidneys.
#
# • Normal range : 3.5 to 5.5 g/dL.
#
# __Albumin and Globulin Ratio(AGR)__ :
# • The Albumin to Globulin ratio (A:G) is the ratio of albumin present in serum in relation to the amount of globulin.
#
# • The ratio can be interpreted only in light of the total protein concentration.
#
# • Very generally speaking, the normal ratio in most species approximates 1:1.
#
# • Normal range : 0.8 to 2.0.

# %% [markdown]
# # Necessary Libaray

# %%
# !pip install imblearn
# Out:
# ...
#   Using cached imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# ...
#      ---------------------------------------- 0.0/226.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/226.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/226.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/226.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/226.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/226.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/226.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/226.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/226.0 kB ? eta -:--:--
#      ----- ------------------------------- 30.7/226.0 kB 131.3 kB/s eta 0:00:02
#      ----- ------------------------------- 30.7/226.0 kB 131.3 kB/s eta 0:00:02
#      ----- ------------------------------- 30.7/226.0 kB 131.3 kB/s eta 0:00:02
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import model_selection
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB 
from sklearn.neighbors import KNeighborsClassifier
from imblearn.over_sampling import SMOTE
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,precision_score,classification_report,f1_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error,confusion_matrix, precision_score, recall_score, auc,roc_curve, roc_auc_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Data Loading

# %%
#loading data using pandas 
data=pd.read_csv("D:\AI\Liver Patients\Indian Liver Patient Dataset.csv")

# %% [markdown]
# # Basic Checks

# %%
#size of data set 
data.shape
# Out:
# (583, 11)

# %%
#first 5 records of data 
data.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Target
# 0      3.3                        0.90       1
# ...

# %%
#Last 5 records of data
data.tail()
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 578   60   Male              0.5               0.1                   500
# 579   40   Male              0.6               0.1                    98
# 580   52   Male              0.8               0.2                   245
# 581   31   Male              1.3               0.5                   184
# 582   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Target
# ...

# %%
# Features of the data 
data.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Target'],
#       dtype='object')

# %%
# datatypes of all features and checking NUll values 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Target                      583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %% [markdown]
# column "Albumin_and_Globulin_ratio" has some data missing in it.

# %%
#stats of data set
data.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %%
#checking the NULL values
data[data['Albumin_and_Globulin_Ratio'].isnull()]
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 209   45  Female              0.9               0.3                   189
# 241   51    Male              0.8               0.2                   230
# 253   35  Female              0.6               0.2                   180
# 312   27    Male              1.3               0.6                   106
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 209                        23                          33             6.6
# 241                        24                          46             6.5
# 253                        12                          15             5.2
# 312                        25                          54             8.5
#
#      Albumin  Albumin_and_Globulin_Ratio  Target
# 209      3.9                         NaN       1
# 241      3.1                         NaN       1
# 253      2.7                         NaN       2
# ...

# %% [markdown]
# Replacing NaN value with the mean value of the 'Albumin_and_Globulin_Ratio' that is 0.94

# %%
data['Albumin_and_Globulin_Ratio']=data['Albumin_and_Globulin_Ratio'].fillna(0.94)

# %%
data=data.rename(columns={'Total_Bilirubin':'TB','Direct_Bilirubin':'DB','Alkaline_Phosphotase':'Alkphos','Alamine_Aminotransferase':'Sgpt','Aspartate_Aminotransferase':'Sgot','Total_Protiens':'TP','Albumin':'ALB','Albumin_and_Globulin_Ratio':'AGR','Target':'Liver_disease'}, inplace=False)#Here to see Null Values# Importing the dataset

# %%
data[data['AGR'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, TB, DB, Alkphos, Sgpt, Sgot, TP, ALB, AGR, Liver_disease]
# Index: []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            583 non-null    int64
#  1   Gender         583 non-null    object
#  2   TB             583 non-null    float64
#  3   DB             583 non-null    float64
#  4   Alkphos        583 non-null    int64
#  5   Sgpt           583 non-null    int64
#  6   Sgot           583 non-null    int64
#  7   TP             583 non-null    float64
#  8   ALB            583 non-null    float64
#  9   AGR            583 non-null    float64
#  10  Liver_disease  583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %% [markdown]
# Now Converting Categorical Data 'Gender' into Numerical Data

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder = LabelEncoder()
data['Is_male'] = LabelEncoder.fit_transform(data['Gender'])
data=data.drop(columns='Gender')

# %%
data['Liver_disease'] = data['Liver_disease'] - 1

# %%
data.head()
# Out:
#    Age    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB   AGR  Liver_disease  Is_male
# 0   65   0.7  0.1      187    16    18  6.8  3.3  0.90              0        0
# 1   62  10.9  5.5      699    64   100  7.5  3.2  0.74              0        1
# 2   62   7.3  4.1      490    60    68  7.0  3.3  0.89              0        1
# 3   58   1.0  0.4      182    14    20  6.8  3.4  1.00              0        1
# 4   72   3.9  2.0      195    27    59  7.3  2.4  0.40              0        1

# %% [markdown]
# ### Insights/Obervation:-
# <ol>
# <li>Shape of Data set is 583 rows and 11 features.
# <li>There were 4 Null value present in Albumin and Globulin Ratio in DataSet which is removed.
# <li>In feature AGE any patient whose age exceeded 89 is listed as being of age "90"
# <li>Features are renamed.
# <li>New Shape of Dataset is 579 rows.
# <li>Gender Column is converted into Numeric form
# <li>Liver_disease columns values is minus by 1 so that Now means 0:Patient with Liver Disease and 1:Patient without Liver disease </ol>

# %% [markdown]
# # Data Visualization

# %%
#univariant analysis of numerical features
data1=data[['Age','Is_male','TB','DB','Alkphos','Sgpt','Sgot','TP','ALB','AGR','Liver_disease']]
plt.figure(figsize=(15,15))
plotnumber=1
for columns in data1:
    if plotnumber<12:
        plt.subplot(4,3,plotnumber)
        plt.hist(data1[columns],color='blue')
        plt.xlabel(columns,fontsize=15)
        plt.ylabel('Count',fontsize=15)
        plotnumber+=1
plt.tight_layout()

# %% [markdown]
# #### Insights/Obervation:-
# <ol>
# <li>Most of the Patients has the Age group from 30 to 70 years age </li>
# <li>Most of the Patients are Male</li>
# <li>Most of the Patients Total Bilirubin ranges from 0.4 to 7</li>
# <li>Most of the Patients Direct Bilirubin ranges from 0.1 to 1.9</li>
# <li>Most of the Patients Alkaline Phosphate ranges from 50 to 200</li>
# <li>Most of the Patients Alamine Aminotransferase ranges from 10 to 200</li>
# <li>Most of the Patients Aspartate Aminotransferase ranges from 10 to 500</li>
# <li>Most of the Patients Total Proteins ranges from 5.5 to 7.5</li>
# <li>Most of the Patients Albumin ranges from 2.3 to 4.1</li>
# <li>Most of the Patients Albumin and Globulin Ratio ranges from 0.7 to 1</li>
# <li>Most of the Patients has the Liver Diseases </li>
# </ol>

# %%
#Count of all features with respect to Liver_Disease
plt.figure(figsize=(25,25),facecolor='white')
plotnumber=1

for column in data:
    if plotnumber<=35:
        ax=plt.subplot(8,5,plotnumber)
        sns.barplot(x=data['Liver_disease'],y=data[column])
        plt.xlabel(column,fontsize=10)
        plt.ylabel('Count',fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(25,25),facecolor='white')
plotnumber=1
for column in data:
    if plotnumber<=35:
        ax=plt.subplot(8,5,plotnumber)
        sns.distplot(data[column], hist=True, rug=True)
        plt.xlabel(column,fontsize=10)
        plt.ylabel('Count',fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
sns.pairplot(data,hue='Liver_disease')

# %%
#Performing Correlation to find the features which are correlated
data.corr()
# Out:
#                     Age        TB        DB   Alkphos      Sgpt      Sgot  \
# Age            1.000000  0.011763  0.007529  0.080425 -0.086883 -0.019910
# TB             0.011763  1.000000  0.874618  0.206669  0.214065  0.237831
# DB             0.007529  0.874618  1.000000  0.234939  0.233894  0.257544
# Alkphos        0.080425  0.206669  0.234939  1.000000  0.125680  0.167196
# Sgpt          -0.086883  0.214065  0.233894  0.125680  1.000000  0.791966
# Sgot          -0.019910  0.237831  0.257544  0.167196  0.791966  1.000000
# TP            -0.187461 -0.008099 -0.000139 -0.028514 -0.042518 -0.025645
# ALB           -0.265924 -0.222250 -0.228531 -0.165453 -0.029742 -0.085290
# AGR           -0.216039 -0.206100 -0.199941 -0.233888 -0.002324 -0.069985
# Liver_disease -0.137351 -0.220208 -0.246046 -0.184866 -0.163416 -0.151934
# Is_male        0.056560  0.089291  0.100436 -0.027496  0.082332  0.080336
#
#                      TP       ALB       AGR  Liver_disease   Is_male
# ...

# %%
plt.figure(figsize=(25,20))
sns.heatmap(data.drop(('Liver_disease'),axis=1).corr(),annot=True,cmap="RdYlGn", annot_kws={"size":15})
# Out:
# <AxesSubplot:>

# %% [markdown]
# __From above Correlation heatmap we found that:__
#
# __TB_total_bilirubin and DB_direct_Bilirubin__,
#
# __ALB_albumin and TP_total_proteins__,
#
# __A/G_Ratio and ALB_albumin__,
#
# __Sgot_Aspartate_Aminotransferase and Sgpt_Alamine_Aminotransferase have a strong positive relationship__

# %% [markdown]
# # Model Creation

# %%
X = data[['Age', 'TB', 'DB','Alkphos','Sgpt','Sgot','TP', 'ALB', 'AGR', 'Is_male']] #Independant Columns
y = data['Liver_disease'] #Dependant Coloumn

# %%
y.value_counts()
# Out:
# 0    416
# 1    167
# Name: Liver_disease, dtype: int64

# %% [markdown]
# ## Balancing the Data using smote(Over Sampling)

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
smote=SMOTE()
x_smote,y_smote=smote.fit_resample(X,y)

# %%
print("Actual Classes",Counter(y))
print("SMOTE Classes",Counter(y_smote))

# %%
# Scaling the data
X_scaler = preprocessing.normalize(x_smote)

# %% [markdown]
# # Spliting Data

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X_scaler,y_smote, random_state = 0)
print("Train Shape: {}".format(X_train.shape))
print("Test Shape: {}".format(X_test.shape))

# %% [markdown]
# # Logistic Regression

# %%
clf = LogisticRegression()
clf.fit(X_train,y_train)
y_pred =clf.predict(X_test)

# %% [markdown]
# # Model Evaluation

# %%
test_roc_auc = roc_auc_score(y_test, y_pred)
print('Test set ROC AUC score: {:.3f}'.format(test_roc_auc))
score = clf.score(X_test, y_test)
print("Score of the model is - ",score)
print("Report of this model - ")
print(metrics.classification_report(y_test, y_pred, digits=3))
print("Accuracy score - ", metrics.accuracy_score(y_test,y_pred))

# %%
cm1 = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(9,9))
sns.heatmap(cm1, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15)

# %% [markdown]
# # Naive Bayes

# %%
nb = GaussianNB()
nb.fit(X_train,y_train)
y_pred_nb = nb.predict(X_test)

# %% [markdown]
# # Model Evaluation

# %%
test_roc_auc = roc_auc_score(y_test, y_pred_nb)
print('Test set ROC AUC score: {:.3f}'.format(test_roc_auc))
score = nb.score(X_test, y_test)
print("Score of the model is - ",score)
print("Report card of this model - ")
print(metrics.classification_report(y_test, y_pred_nb, digits=3))
print("Accuracy score - ", metrics.accuracy_score(y_test,y_pred_nb))

# %%
cm2 = metrics.confusion_matrix(y_test, y_pred_nb)
plt.figure(figsize=(9,9))
sns.heatmap(cm2, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15)

# %% [markdown]
# # K-Nearest Neighbor

# %%
error_rate = []
for i in range(1,11):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,11),error_rate,color='blue', linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')

# %%
knn = KNeighborsClassifier(n_neighbors=8)
knn.fit(X_train,y_train)
y_pred_knn = knn.predict(X_test)

# %% [markdown]
# #  Model Evaluation

# %%
test_roc_auc = roc_auc_score(y_test, y_pred_knn)
print('Test set ROC AUC score: {:.3f}'.format(test_roc_auc))
score = knn.score(X_test, y_test)
print("Score of the model is - ",score)
print("Report card of this model - ")
print(metrics.classification_report(y_test, y_pred_knn, digits=3))
print("Accuracy score - ", metrics.accuracy_score(y_test,y_pred_knn))

# %%
cm4 = metrics.confusion_matrix(y_test, y_pred_knn)
plt.figure(figsize=(9,9))
sns.heatmap(cm4, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Accent');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15)

# %% [markdown]
# # Descision Tree

# %%
dtree = DecisionTreeClassifier(max_depth = None , random_state = 2 , max_features = None, min_samples_leaf =20)
dtree.fit(X_train,y_train)
y_pred_dtree = dtree.predict(X_test)

# %% [markdown]
# # Model Evaluation

# %%
test_roc_auc = roc_auc_score(y_test, y_pred_dtree)
print('Test set ROC AUC score: {:.3f}'.format(test_roc_auc))
score = dtree.score(X_test, y_test)
print("Score of the model is - ",score)
print("Report card of this model - ")
print(metrics.classification_report(y_test, y_pred_dtree, digits=3))
print("Accuracy score - ", metrics.accuracy_score(y_test,y_pred_dtree))

# %%
cm5 = metrics.confusion_matrix(y_test, y_pred_dtree)
plt.figure(figsize=(9,9))
sns.heatmap(cm5, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'viridis');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15)

# %% [markdown]
# # Random Forest

# %%
rf_clf = RandomForestClassifier(n_estimators=80)
rf_clf.fit(X_train,y_train)
y_predict=rf_clf.predict(X_test)

# %% [markdown]
# #  Model Evaluation

# %%
test_roc_auc = roc_auc_score(y_test,y_predict)
score = rf_clf.score(X_test, y_test)
print("Score of the model is - ",score)
print("Report card of this model - ")
print(metrics.classification_report(y_test,y_predict, digits=3))
print("Accuracy score - ", metrics.accuracy_score(y_test,y_predict))

# %%
cm6 = metrics.confusion_matrix(y_test, y_predict)
plt.figure(figsize=(9,9))
sns.heatmap(cm6, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'viridis');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15)

# %% [markdown]
# # Support Vector Machine

# %%
svclassifier = SVC()
svclassifier.fit(X_train, y_train)

# %%
y_hat=svclassifier.predict(X_test)

# %% [markdown]
# # Model Evaluation

# %%
test_roc_auc = roc_auc_score(y_test, y_predict)
print('Test set ROC AUC score: {:.3f}'.format(test_roc_auc))
print(classification_report(y_test,y_hat))

# %%
cm6 = metrics.confusion_matrix(y_test, y_predict)
plt.figure(figsize=(9,9))
sns.heatmap(cm6, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'viridis');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15)

# %% [markdown]
# # Cross-Validation

# %%
model_pipeline =[]
model_pipeline.append(LogisticRegression(solver="liblinear"))
model_pipeline.append(SVC())
model_pipeline.append(KNeighborsClassifier())
model_pipeline.append(DecisionTreeClassifier())
model_pipeline.append(RandomForestClassifier())
model_pipeline.append(GaussianNB())

# %%
model = {"LogisticRegression()","SVC()","GaussianNB()","RandomForestClassifier()","KNeighborsClassifier()","DecisionTreeClassifier()"}
model_list = ["Logistic Regression","SVM","Naive Bayes","Random Tree","KNN","Descision Tress"]#print(result)
scores=[]
acc_list=[] 
auc_list1=[]
pre_list=[]
Recall_list=[]
F1_score=[]
Classic_report=[]
for model in model_pipeline:
    model.fit(X_train,y_train)
    y_pred= model.predict(X_test)
    acc_list.append(metrics.accuracy_score(y_test,y_pred))
    fpr,tpr, _thresholds =metrics.roc_curve(y_test,y_pred)
    auc_list1.append(round(metrics.auc(fpr,tpr),2))
    pre_list.append(precision_score(y_test,y_pred))
    Recall_list.append(recall_score(y_test,y_pred))
    F1_score.append(f1_score(y_test,y_pred))
    Classic_report.append(classification_report(y_test,y_pred))
    scores.append(cross_val_score(model, X_test, y_test, cv=10, scoring ='accuracy').mean()) #Applied 10-k fold cross validation

# %% [markdown]
# # Final Result

# %%
result=pd.DataFrame({"Model":model_list, "Accuracy":acc_list,"AUC":auc_list1,"f1_score":F1_score,"CV_Score":scores})
result

# %% [markdown]
# # Conclusion :

# %% [markdown]
# __The Liver Pateint Prediction Dataset contains 416 liver patient records and 167 non-liver patient records collected from North East of Andhra Pradesh, India. Out of which 441 male patient records and 142 female patient records.So after observing we know that it is an imbalance dataset so to overcome this we applied the Smote as to Balance dataset by doing Over Sampling. After which we Applied many Machine learning Algorithms as Logistic Regression, Naive Bayes,K-Nearest Neighbors,Support Vector Machine, Random forest and Descision Tree. Out of which we get the K-Nearest Neighbor as the best fit Algorithm for the Dataset.__
